# %%
import plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
import cufflinks
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)

import pandas as pd
import numpy as np
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
import plotly.express as px

# %%
x = np.arange(-1.5, 2.1, 0.001)
y = 4*(x**2) - 3*x + 5
#x_0 = 3/8
#y_0 = 4*(x_0**2) - 3*x_0 + 5
px.line(y, x, y).show()
#px.scatter(y, x_0, y_0).update_traces(marker_size=30);
# Out:
# <div>                            <div id="72e6ec17-bd6d-47f6-8293-289a72803072" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72e6ec17-bd6d-47f6-8293-289a72803072")) {                    Plotly.newPlot(                        "72e6ec17-bd6d-47f6-8293-289a72803072",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[-1.5,-1.499,-1.4980000000000002,-1.4970000000000003,-1.4960000000000004,-1.4950000000000006,-1.4940000000000007,-1.4930000000000008,-1.4920000000000009,-1.491000000000001,-1.490000000000001,-1.4890000000000012,-1.4880000000000013,-1.4870000000000014,-1.4860000000000015,-1.485000
# ...

# %%
go.Figure(data=go.Scatter(x=x, y=y)).show();
# Out:
# <div>                            <div id="94738b11-f0ae-4c5f-9925-1ee171aa1df2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94738b11-f0ae-4c5f-9925-1ee171aa1df2")) {                    Plotly.newPlot(                        "94738b11-f0ae-4c5f-9925-1ee171aa1df2",                        [{"x":[-1.5,-1.499,-1.4980000000000002,-1.4970000000000003,-1.4960000000000004,-1.4950000000000006,-1.4940000000000007,-1.4930000000000008,-1.4920000000000009,-1.491000000000001,-1.490000000000001,-1.4890000000000012,-1.4880000000000013,-1.4870000000000014,-1.4860000000000015,-1.4850000000000017,-1.4840000000000018,-1.4830000000000019,-1.482000000000002,-1.481000000000002,-1.4800000000000022,-1.4790000000000023,-1.4780000000000024,-1.4770000000000025,-1.4760000000
# ...

# %%
import matplotlib.pyplot as plt

# %%
#Нарисовать просто, и точку просто поставить!

x = np.arange(-1.5, 2.1, 0.001)
y = 4*(x**2) - 3*x + 5

x_0 = 3/8
y_0 = 4*(x_0**2) - 3*x_0 + 5

plt.figure(figsize=(7, 5))
plt.plot(x, y);
plt.scatter(x_0, y_0, c='r')
y1 = 8 * x - 3
plt.plot(x, y1);

# %%
#Нарисовать просто, и точку просто поставить!

x = np.arange(-5, 2, 0.01)
y = x**4 + 5 * x**3 -10 * x
yd = 4 * x**3 + 15 * x**2 - 10
y2d = 12 * x**2 + 30 * x

plt.figure(figsize=(7, 5))
plt.plot(x, y)
plt.plot(x, yd)
plt.plot(x, y2d)
plt.ylim(None, 100);
